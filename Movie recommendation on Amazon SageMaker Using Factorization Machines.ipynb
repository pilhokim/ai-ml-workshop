# %% [markdown]
# # Movie recommendation on Amazon SageMaker with Factorization Machines

# %% [markdown]
# Recommendation is one of the most popular applications in machine learning (ML). This lab is a modified version of [Build a movie recommender with factorization machines on Amazon SageMaker](https://aws.amazon.com/blogs/machine-learning/build-a-movie-recommender-with-factorization-machines-on-amazon-sagemaker/) AWS ML blog. It will show you how to build a movie recommendation model based on factorization machines — one of the built-in algorithms of Amazon SageMaker — and the popular [MovieLens](https://grouplens.org/datasets/movielens/) dataset.

# %% [markdown]
# This lab will take around 12 minutes.

# %% [markdown]
# ## A word about factorization machines

# %% [markdown]
# Factorization Machines (FM) are a supervised machine learning technique introduced in 2010 ([research paper](https://www.csie.ntu.edu.tw/~b97053/paper/Rendle2010FM.pdf), PDF). FM get their name from their ability to reduce problem dimensionality thanks to matrix factorization.
#
# Factorization machines can be used for classification or regression and are much more computationally efficient on large sparse data sets than traditional algorithms like linear regression. This property is why FM are widely used for recommendation. User count and item count are typically very large although the actual number of recommendations is very small (users don’t rate all available items!).
#
# Here’s a simple example: Where a sparse rating matrix (dimension 4×4) is factored into a dense user matrix (dimension 4×2) and a dense item matrix (2×4). As you can see, the number of factors (2) is smaller than the number of columns of the rating matrix (4). In addition, this multiplication also lets us fill all blank values in the rating matrix, which we can then use to recommend new items to any user.

# %% [markdown]
# <img src="images/Factorization2.png" alt="Factorization" style="width: 800px;"/>

# %% [markdown]
# ### The MovieLens dataset

# %% [markdown]
# This dataset is a great starting point for recommendation. It comes in multiples sizes. In this blog post we’ll use ml100k: 100,000 ratings from 943 users on 1682 movies. As you can see, the ml100k rating matrix is quite sparse (93.6% to be precise) because  it only holds 100,000 ratings out of a possible 1,586,126 (943*1682).
#
# Here are the first 10 lines in the data set: user 754 gave movie 595 a 2-star rating, and so on.
#
# <pre>
# # user id, movie id, rating, timestamp
# 754         595         2    879452073
# 932         157         4    891250667
# 751         100         4    889132252
# 101         820         3    877136954
# 606         1277        3    878148493
# 581         475         4    879641850
# 13          50          5    882140001
# 457         59          5    882397575
# 111         321         3    891680076
# 123         657         4    879872066
# </pre>

# %% [markdown]
# ## Recommendation Engine Implementation

# %%
import time                                          #1
print time.strftime("%m/%d/%Y %H:%M:%S")             #2
# Out:
# 09/05/2018 03:47:49

# %%
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer

import boto3, csv, io, json
import numpy as np
from scipy.sparse import lil_matrix

bucket = 'pilho-sagemaker-ai-workshop'
prefix = 'sagemaker/fm-movielens'

# %% [markdown]
# ### Download ml-100k dataset

# %%
# !wget http://files.grouplens.org/datasets/movielens/ml-100k.zip
# !unzip -o ml-100k.zip
# Out:
# --2018-09-05 01:29:43--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.34.235
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.34.235|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip’
#
# ml-100k.zip         100%[===================>]   4.70M  20.2MB/s    in 0.2s
#
# 2018-09-05 01:29:43 (20.2 MB/s) - ‘ml-100k.zip’ saved [4924029/4924029]
#
# Archive:  ml-100k.zip
#    creating: ml-100k/
#   inflating: ml-100k/allbut.pl
#   inflating: ml-100k/mku.sh
#   inflating: ml-100k/README
#   inflating: ml-100k/u.data
#   inflating: ml-100k/u.genre
#   inflating: ml-100k/u.info
#   inflating: ml-100k/u.item
#   inflating: ml-100k/u.occupation
#   inflating: ml-100k/u.user
#   inflating: ml-100k/u1.base
#   inflating: ml-100k/u1.test
#   inflating: ml-100k/u2.base
#   inflating: ml-100k/u2.test
#   inflating: ml-100k/u3.base
#   inflating: ml-100k/u3.test
#   inflating: ml-100k/u4.base
#   inflating: ml-100k/u4.test
#   inflating: ml-100k/u5.base
#   inflating: ml-100k/u5.test
#   inflating: ml-100k/ua.base
#   inflating: ml-100k/ua.test
#   inflating: ml-100k/ub.base
#   inflating: ml-100k/ub.test

# %%
# %cd ml-100k
# !shuf ua.base -o ua.base.shuffled
# !head -10 ua.base.shuffled
# Out:
# /home/ec2-user/SageMaker/pilho-lab/HotelSila/ml-100k
# 707	211	3	886287051
# 346	55	5	874948639
# 488	845	3	891294853
# 359	323	3	886453431
# 443	260	1	883504818
# 59	58	4	888204389
# 351	689	4	879481386
# 487	288	4	883440572
# 318	485	5	884495921
# 660	209	4	891406212

# %%
# !head -10 ua.test
# Out:
# 1	20	4	887431883
# 1	33	4	878542699
# 1	61	4	878542420
# 1	117	3	874965739
# 1	155	2	878542201
# 1	160	4	875072547
# 1	171	5	889751711
# 1	189	3	888732928
# 1	202	5	875072442
# 1	265	4	878542441

# %% [markdown]
# ### Build training set and test set

# %%
nbUsers=943
nbMovies=1682
nbFeatures=nbUsers+nbMovies

nbRatingsTrain=90570
nbRatingsTest=9430

# %%
# For each user, build a list of rated movies.
# We'd need this to add random negative samples.
moviesByUser = {}
for userId in range(nbUsers):
    moviesByUser[str(userId)]=[]
 
with open('ua.base.shuffled','r') as f:
    samples=csv.reader(f,delimiter='\t')
    for userId,movieId,rating,timestamp in samples:
        moviesByUser[str(int(userId)-1)].append(int(movieId)-1)

# %%
def loadDataset(filename, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line=0
    with open(filename,'r') as f:
        samples=csv.reader(f,delimiter='\t')
        for userId,movieId,rating,timestamp in samples:
            X[line,int(userId)-1] = 1
            X[line,int(nbUsers)+int(movieId)-1] = 1
            if int(rating) >= 4:
                Y.append(1)
            else:
                Y.append(0)
            line=line+1
            
    Y=np.array(Y).astype('float32')
    return X,Y

# %%
X_train, Y_train = loadDataset('ua.base.shuffled', nbRatingsTrain, nbFeatures)
X_test, Y_test = loadDataset('ua.test',nbRatingsTest,nbFeatures)

# %%
print(X_train[1000])
# Out:
#   (0, 275)	1.0
#   (0, 1297)	1.0

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (nbRatingsTrain, nbFeatures)
assert Y_train.shape == (nbRatingsTrain, )
zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (zero_labels, nbRatingsTrain-zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (nbRatingsTest, nbFeatures)
assert Y_test.shape  == (nbRatingsTest, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, nbRatingsTest-zero_labels))
# Out:
# (90570, 2625)
# (90570,)
# Training labels: 49906 zeros, 40664 ones
# (9430, 2625)
# (9430,)
# Test labels: 5469 zeros, 3961 ones

# %% [markdown]
# ### Convert to protobuf and save to S3

# %%
train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train3')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test3')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %%
def writeDatasetToProtobuf(X, Y, bucket, prefix, key):
    buf = io.BytesIO()
    smac.write_spmatrix_to_sparse_tensor(buf, X, Y)
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
train_data = writeDatasetToProtobuf(X_train, Y_train, bucket, train_prefix, train_key)    
test_data  = writeDatasetToProtobuf(X_test, Y_test, bucket, test_prefix, test_key)    
  
print(train_data)
print(test_data)
print('Output: {}'.format(output_prefix))
# Out:
# s3://pilho-sagemaker-ai-workshop/sagemaker/fm-movielens/train3/train.protobuf
# s3://pilho-sagemaker-ai-workshop/sagemaker/fm-movielens/test3/test.protobuf
# Output: s3://pilho-sagemaker-ai-workshop/sagemaker/fm-movielens/output

# %% [markdown]
# ### Run training job

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(boto3.Session().region_name, 'factorization-machines')

# %%
fm = sagemaker.estimator.Estimator(container,
                                   get_execution_role(), 
                                   train_instance_count=1, 
                                   train_instance_type='ml.c4.xlarge',
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm.set_hyperparameters(feature_dim=nbFeatures,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=100)

fm.fit({'train': train_data, 'test': test_data})
# Out:
# INFO:sagemaker:Creating training-job with name: factorization-machines-2018-09-05-01-30-02-100
# .....................
# Docker entrypoint called with argument(s): train
# [09/05/2018 01:33:20 INFO 140343674808128] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
#
, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1536111212.952727, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1536111212.18301}
#
# [09/05/2018 01:33:32 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=117652.559402 records/second
# [09/05/2018 01:33:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_accuracy <score>=0.731
# [09/05/2018 01:33:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_cross_entropy <loss>=0.588405395508
# [09/05/2018 01:33:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_f_1.000 <score>=0.753888380604
# [09/05/2018 01:33:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=16, train binary_classification_accuracy <score>=0.723681318681
# [09/05/2018 01:33:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=16, train binary_classification_cross_entropy <loss>=0.586272633312
# [09/05/2018 01:33:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=16, train binary_f_1.000 <score>=0.767574062948
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 726.8249988555908, "sum": 726.8249988555908, "min": 726.8249988555908}}, "EndTime": 1536111213.679875, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111212.952562}
#
# [09/05/2018 01:33:33 INFO 140343674808128] #progress_metric: host=algo-1, completed 17 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1548, "sum": 1548.0, "min": 1548}, "Total Records Seen": {"count": 1, "max": 1540690, "sum": 1540690.0, "min": 1540690}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1536111213.680104, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1536111212.953018}
#
# [09/05/2018 01:33:33 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=124542.606018 records/second
# [09/05/2018 01:33:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_accuracy <score>=0.73
# [09/05/2018 01:33:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_cross_entropy <loss>=0.585430053711
# [09/05/2018 01:33:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_f_1.000 <score>=0.752747252747
# [09/05/2018 01:33:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=17, train binary_classification_accuracy <score>=0.724945054945
# [09/05/2018 01:33:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=17, train binary_classification_cross_entropy <loss>=0.583282781915
# [09/05/2018 01:33:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=17, train binary_f_1.000 <score>=0.767862442499
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 743.9239025115967, "sum": 743.9239025115967, "min": 743.9239025115967}}, "EndTime": 1536111214.424394, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111213.679946}
#
# [09/05/2018 01:33:34 INFO 140343674808128] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1639, "sum": 1639.0, "min": 1639}, "Total Records Seen": {"count": 1, "max": 1631260, "sum": 1631260.0, "min": 1631260}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1536111214.424741, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1536111213.680443}
#
# [09/05/2018 01:33:34 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=121663.85574 records/second
# [09/05/2018 01:33:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_accuracy <score>=0.731
# [09/05/2018 01:33:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_cross_entropy <loss>=0.582672973633
# [09/05/2018 01:33:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_f_1.000 <score>=0.752984389348
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=18, train binary_classification_accuracy <score>=0.725725274725
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=18, train binary_classification_cross_entropy <loss>=0.580488518013
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=18, train binary_f_1.000 <score>=0.767773570159
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 748.0111122131348, "sum": 748.0111122131348, "min": 748.0111122131348}}, "EndTime": 1536111215.174369, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111214.424462}
#
# [09/05/2018 01:33:35 INFO 140343674808128] #progress_metric: host=algo-1, completed 19 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1730, "sum": 1730.0, "min": 1730}, "Total Records Seen": {"count": 1, "max": 1721830, "sum": 1721830.0, "min": 1721830}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 20, "sum": 20.0, "min": 20}}, "EndTime": 1536111215.174562, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 18}, "StartTime": 1536111214.42633}
#
# [09/05/2018 01:33:35 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=121026.080339 records/second
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=19, batch=0 train binary_classification_accuracy <score>=0.729
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=19, batch=0 train binary_classification_cross_entropy <loss>=0.58011315918
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=19, batch=0 train binary_f_1.000 <score>=0.752058554437
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=19, train binary_classification_accuracy <score>=0.726692307692
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=19, train binary_classification_cross_entropy <loss>=0.577871063568
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=19, train binary_f_1.000 <score>=0.767983581324
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 756.6828727722168, "sum": 756.6828727722168, "min": 756.6828727722168}}, "EndTime": 1536111215.931553, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111215.174432}
#
# [09/05/2018 01:33:35 INFO 140343674808128] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1821, "sum": 1821.0, "min": 1821}, "Total Records Seen": {"count": 1, "max": 1812400, "sum": 1812400.0, "min": 1812400}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 21, "sum": 21.0, "min": 21}}, "EndTime": 1536111215.931766, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 19}, "StartTime": 1536111215.174841}
#
# [09/05/2018 01:33:35 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=119639.075851 records/second
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=20, batch=0 train binary_classification_accuracy <score>=0.732
# [09/05/2018 01:33:35 INFO 140343674808128] #quality_metric: host=algo-1, epoch=20, batch=0 train binary_classification_cross_entropy <loss>=0.577731506348
# ...
# [09/05/2018 01:34:29 INFO 140343674808128] #quality_metric: host=algo-1, epoch=94, batch=0 train binary_classification_accuracy <score>=0.752
# [09/05/2018 01:34:29 INFO 140343674808128] #quality_metric: host=algo-1, epoch=94, batch=0 train binary_classification_cross_entropy <loss>=0.525750305176
# [09/05/2018 01:34:29 INFO 140343674808128] #quality_metric: host=algo-1, epoch=94, batch=0 train binary_f_1.000 <score>=0.777378815081
# [09/05/2018 01:34:30 INFO 140343674808128] #quality_metric: host=algo-1, epoch=94, train binary_classification_accuracy <score>=0.749186813187
# [09/05/2018 01:34:30 INFO 140343674808128] #quality_metric: host=algo-1, epoch=94, train binary_classification_cross_entropy <loss>=0.515040249667
# [09/05/2018 01:34:30 INFO 140343674808128] #quality_metric: host=algo-1, epoch=94, train binary_f_1.000 <score>=0.778944309927
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 734.7080707550049, "sum": 734.7080707550049, "min": 734.7080707550049}}, "EndTime": 1536111270.683912, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111269.948709}
#
# [09/05/2018 01:34:30 INFO 140343674808128] #progress_metric: host=algo-1, completed 95 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8646, "sum": 8646.0, "min": 8646}, "Total Records Seen": {"count": 1, "max": 8605150, "sum": 8605150.0, "min": 8605150}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 96, "sum": 96.0, "min": 96}}, "EndTime": 1536111270.684106, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 94}, "StartTime": 1536111269.949168}
#
# [09/05/2018 01:34:30 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=123212.23737 records/second
# [09/05/2018 01:34:30 INFO 140343674808128] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_accuracy <score>=0.752
# [09/05/2018 01:34:30 INFO 140343674808128] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_classification_cross_entropy <loss>=0.52547277832
# [09/05/2018 01:34:30 INFO 140343674808128] #quality_metric: host=algo-1, epoch=95, batch=0 train binary_f_1.000 <score>=0.777378815081
# [09/05/2018 01:34:31 INFO 140343674808128] #quality_metric: host=algo-1, epoch=95, train binary_classification_accuracy <score>=0.749351648352
# [09/05/2018 01:34:31 INFO 140343674808128] #quality_metric: host=algo-1, epoch=95, train binary_classification_cross_entropy <loss>=0.514700384119
# [09/05/2018 01:34:31 INFO 140343674808128] #quality_metric: host=algo-1, epoch=95, train binary_f_1.000 <score>=0.7791002857
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 731.6689491271973, "sum": 731.6689491271973, "min": 731.6689491271973}}, "EndTime": 1536111271.416148, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111270.683981}
#
# [09/05/2018 01:34:31 INFO 140343674808128] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8737, "sum": 8737.0, "min": 8737}, "Total Records Seen": {"count": 1, "max": 8695720, "sum": 8695720.0, "min": 8695720}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1536111271.416435, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 95}, "StartTime": 1536111270.68445}
#
# [09/05/2018 01:34:31 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=123713.089358 records/second
# [09/05/2018 01:34:31 INFO 140343674808128] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_accuracy <score>=0.752
# [09/05/2018 01:34:31 INFO 140343674808128] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_classification_cross_entropy <loss>=0.525197021484
# [09/05/2018 01:34:31 INFO 140343674808128] #quality_metric: host=algo-1, epoch=96, batch=0 train binary_f_1.000 <score>=0.777378815081
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=96, train binary_classification_accuracy <score>=0.749395604396
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=96, train binary_classification_cross_entropy <loss>=0.514363300701
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=96, train binary_f_1.000 <score>=0.77913474669
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 691.0388469696045, "sum": 691.0388469696045, "min": 691.0388469696045}}, "EndTime": 1536111272.107851, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111271.416215}
#
# [09/05/2018 01:34:32 INFO 140343674808128] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8828, "sum": 8828.0, "min": 8828}, "Total Records Seen": {"count": 1, "max": 8786290, "sum": 8786290.0, "min": 8786290}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1536111272.10804, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 96}, "StartTime": 1536111271.416786}
#
# [09/05/2018 01:34:32 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=130996.563437 records/second
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_accuracy <score>=0.752
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_classification_cross_entropy <loss>=0.524922973633
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=97, batch=0 train binary_f_1.000 <score>=0.777378815081
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=97, train binary_classification_accuracy <score>=0.749659340659
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=97, train binary_classification_cross_entropy <loss>=0.514028841459
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=97, train binary_f_1.000 <score>=0.779380005617
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 748.6200332641602, "sum": 748.6200332641602, "min": 748.6200332641602}}, "EndTime": 1536111272.856992, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111272.107913}
#
# [09/05/2018 01:34:32 INFO 140343674808128] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 8919, "sum": 8919.0, "min": 8919}, "Total Records Seen": {"count": 1, "max": 8876860, "sum": 8876860.0, "min": 8876860}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1536111272.857217, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 97}, "StartTime": 1536111272.108343}
#
# [09/05/2018 01:34:32 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=120924.757891 records/second
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_accuracy <score>=0.752
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_classification_cross_entropy <loss>=0.524650390625
# [09/05/2018 01:34:32 INFO 140343674808128] #quality_metric: host=algo-1, epoch=98, batch=0 train binary_f_1.000 <score>=0.777378815081
# [09/05/2018 01:34:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=98, train binary_classification_accuracy <score>=0.749802197802
# [09/05/2018 01:34:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=98, train binary_classification_cross_entropy <loss>=0.513696862525
# [09/05/2018 01:34:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=98, train binary_f_1.000 <score>=0.779512308497
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 733.9780330657959, "sum": 733.9780330657959, "min": 733.9780330657959}}, "EndTime": 1536111273.591524, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111272.857069}
#
# [09/05/2018 01:34:33 INFO 140343674808128] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9010, "sum": 9010.0, "min": 9010}, "Total Records Seen": {"count": 1, "max": 8967430, "sum": 8967430.0, "min": 8967430}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1536111273.59174, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 98}, "StartTime": 1536111272.857513}
#
# [09/05/2018 01:34:33 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=123336.248882 records/second
# [09/05/2018 01:34:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_accuracy <score>=0.752
# [09/05/2018 01:34:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_classification_cross_entropy <loss>=0.524379272461
# [09/05/2018 01:34:33 INFO 140343674808128] #quality_metric: host=algo-1, epoch=99, batch=0 train binary_f_1.000 <score>=0.777378815081
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=99, train binary_classification_accuracy <score>=0.749989010989
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=99, train binary_classification_cross_entropy <loss>=0.51336723009
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, epoch=99, train binary_f_1.000 <score>=0.779666269599
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.749989010989
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.51336723009
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.779666269599
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 728.0328273773193, "sum": 728.0328273773193, "min": 728.0328273773193}}, "EndTime": 1536111274.320179, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111273.591592}
#
# [09/05/2018 01:34:34 INFO 140343674808128] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 9101, "sum": 9101.0, "min": 9101}, "Total Records Seen": {"count": 1, "max": 9058000, "sum": 9058000.0, "min": 9058000}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 101, "sum": 101.0, "min": 101}}, "EndTime": 1536111274.320401, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 99}, "StartTime": 1536111273.592117}
#
# [09/05/2018 01:34:34 INFO 140343674808128] #throughput_metric: host=algo-1, train throughput=124339.639031 records/second
# [09/05/2018 01:34:34 WARNING 140343674808128] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/05/2018 01:34:34 INFO 140343674808128] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 2.462148666381836, "sum": 2.462148666381836, "min": 2.462148666381836}}, "EndTime": 1536111274.323196, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111274.320257}
#
# [09/05/2018 01:34:34 INFO 140343674808128] Saved checkpoint to "/tmp/tmpZ3CzEk/state-0001.params"
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Batches Since Last Reset": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Records Since Last Reset": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Total Batches Seen": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Total Records Seen": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Max Records Seen Between Resets": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1536111274.377598, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111274.328805}
#
# [09/05/2018 01:34:34 INFO 140343674808128] #test_score (algo-1) : ('binary_classification_accuracy', 0.69119830328738074)
# [09/05/2018 01:34:34 INFO 140343674808128] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.58145430919853525)
# [09/05/2018 01:34:34 INFO 140343674808128] #test_score (algo-1) : ('binary_f_1.000', 0.7262643354013912)
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.691198303287
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.581454309199
# [09/05/2018 01:34:34 INFO 140343674808128] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.726264335401
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 73500.17499923706, "sum": 73500.17499923706, "min": 73500.17499923706}, "setuptime": {"count": 1, "max": 35.7050895690918, "sum": 35.7050895690918, "min": 35.7050895690918}}, "EndTime": 1536111274.379454, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1536111274.32326}
# Billable seconds: 185

# %% [markdown]
# ### Deploy model

# %%
fm_predictor = fm.deploy(instance_type='ml.c4.xlarge', initial_instance_count=1)
# Out:
# INFO:sagemaker:Creating model with name: factorization-machines-2018-09-05-01-35-16-223
# INFO:sagemaker:Creating endpoint with name factorization-machines-2018-09-05-01-30-02-100
# ---------------------------------------------------------------------------!

# %%
def fm_serializer(data):
    js = {'instances': []}
    for row in data:
        js['instances'].append({'features': row.tolist()})
    #print js
    return json.dumps(js)

fm_predictor.content_type = 'application/json'
fm_predictor.serializer = fm_serializer
fm_predictor.deserializer = json_deserializer

# %% [markdown]
# ## Run predictions

# %% [markdown]
# Let's test the performance. We will perform a batch prediction on below 10 test sets.

# %%
print(X_test[1000:1010])
# Out:
#   (0, 100)	1.0
#   (0, 1164)	1.0
#   (1, 100)	1.0
#   (1, 1194)	1.0
#   (2, 100)	1.0
#   (2, 1223)	1.0
#   (3, 100)	1.0
#   (3, 1224)	1.0
#   (4, 100)	1.0
#   (4, 1246)	1.0
#   (5, 100)	1.0
#   (5, 1311)	1.0
#   (6, 100)	1.0
#   (6, 1347)	1.0
#   (7, 100)	1.0
#   (7, 1413)	1.0
#   (8, 100)	1.0
#   (8, 1538)	1.0
#   (9, 100)	1.0
#   (9, 1771)	1.0

# %% [markdown]
# In the above cell output, each test set contains two non-zero values (ex, (0,100) and (0,1164). The first one (100) indicates the user ID and the second one subtrated by the total user count (1164 - nbUsers) indicates the movie ID.

# %%
result = fm_predictor.predict(X_test[1000:1010].toarray())
print(result)
# Out:
# {u'predictions': [{u'score': 0.6599310040473938, u'predicted_label': 1.0}, {u'score': 0.1793009489774704, u'predicted_label': 0.0}, {u'score': 0.2245723009109497, u'predicted_label': 0.0}, {u'score': 0.5920941233634949, u'predicted_label': 1.0}, {u'score': 0.5138829350471497, u'predicted_label': 1.0}, {u'score': 0.1430586725473404, u'predicted_label': 0.0}, {u'score': 0.37031662464141846, u'predicted_label': 0.0}, {u'score': 0.4893360137939453, u'predicted_label': 0.0}, {u'score': 0.34443169832229614, u'predicted_label': 0.0}, {u'score': 0.11674283444881439, u'predicted_label': 0.0}]}

# %% [markdown]
# Let's test a whole batch of data and evaluate our predictive accuracy. We will firstly see the prediction result on the training set.

# %%
import numpy as np

predictions = []
for array in np.array_split(X_train[0:20000].toarray(), 100):
    result = fm_predictor.predict(array)
    predictions += [r['predicted_label'] for r in result['predictions']]

predictions = np.array(predictions)

# %%
import pandas as pd

pd.crosstab(Y_train[0:20000], predictions, rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions   0.0   1.0
# actuals
# 0.0          6580  2451
# 1.0          2584  8385

# %% [markdown]
# Let's now check the prediction result on the test set which was not used in the training process.

# %%
import numpy as np

predictions = []
for array in np.array_split(X_test.toarray(), 100):
    result = fm_predictor.predict(array)
    predictions += [r['predicted_label'] for r in result['predictions']]

predictions = np.array(predictions)

# %%
print(X_test.toarray().shape)
# Out:
# (9430, 2625)

# %%
print(Y_test.shape)
# Out:
# (9430,)

# %%
print(predictions.shape)
# Out:
# (9430,)

# %%
pd.crosstab(Y_test, predictions, rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions   0.0   1.0
# actuals
# 0.0          2655  1306
# 1.0          1606  3863

# %%
import time                                          #1
print time.strftime("%m/%d/%Y %H:%M:%S")             #2
# Out:
# 09/05/2018 07:27:50

# %% [markdown]
# ## Online-demo

# %% [markdown]
# Hoang and Alastair developed an online demo based on [Simon's blog](https://medium.com/@julsimon/building-a-movie-recommender-with-factorization-machines-on-amazon-sagemaker-cedbfc8c93d8) which is available at the below link. Their demo includes training cases using bigger data set (20 million) too.

# %% [markdown]
# * http://sagemaker-nab-demo.s3-website-us-west-2.amazonaws.com/

# %% [markdown]
# ## References

# %% [markdown]
# * Original blog: [Build a movie recommender with factorization machines on Amazon SageMaker](https://aws.amazon.com/blogs/machine-learning/build-a-movie-recommender-with-factorization-machines-on-amazon-sagemaker/)
